# %%
import pandas as pd
import numpy as np

# %%
FILENAME = 'topic_mapping_03'
df = pd.read_csv("../data/" + FILENAME  +".csv")
df
# Out:
#                                           debate_topic  debate_index  \
# 0    ['präsident', 'gesetzentwurf', 'gesagt', 'weil...            -1
# 1    ['epidemischen', 'epidemische', 'coronakrise',...             0
# 2    ['präsidentin', 'minister', 'bedanken', 'disku...             1
# 3    ['politik', 'demokratie', 'partei', 'parlament...             2
# 4    ['migrationspolitik', 'migrationspakt', 'einwa...             3
# ..                                                 ...           ...
# 128  ['aserbaidschanische', 'aserbaidschan', 'armen...           127
# 129  ['krisen', 'krise', 'bündnispolitisch', 'krise...           128
# 130  ['verfassungsadäquates', 'verfassungsadäquat',...           129
# 131  ['rechtsextremismus', 'linksextremismus', 'ext...           130
# 132  ['stiftungsbeirat', 'verwaltungsföderalismus',...           131
#
#                                        twitter_1_topic  twitter_1_index  \
# ...

# %%
df.sort_values(by='score', ascending=False, inplace=True)
df
# Out:
#                                           debate_topic  debate_index  \
# 25   ['brexit', 'brexits', 'großbritanniens', 'groß...            24
# 31   ['russlandpolitik', 'russland', 'wladimir', 'r...            30
# 43   ['israel', 'israels', 'israelische', 'israelis...            42
# 6    ['europapolitik', 'europawahl', 'europäisches'...             5
# 125  ['venezuela', 'venezuelas', 'venezolaner', 've...           124
# ..                                                 ...           ...
# 132  ['stiftungsbeirat', 'verwaltungsföderalismus',...           131
# 69   ['kulturstaatsministerin', 'kulturpolitiker', ...            68
# 124  ['filmpolitik', 'filmbranche', 'filmförderungs...           123
# 110  ['patentrechts', 'patentgesetz', 'patentrecht'...           109
# 117  ['arbeitszeitgesetz', 'arbeitszeitgesetzes', '...           116
#
#                                        twitter_1_topic  twitter_1_index  \
# ...

# %%
df.to_csv("../data/"  + FILENAME+ ".csv", index=False)

df.to_excel("../data/"+FILENAME +".xlsx", index=False)
