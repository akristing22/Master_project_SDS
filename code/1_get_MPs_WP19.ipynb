# %%
import pandas as pd
import datetime

# %%
legislative_period_19_begin = datetime.date(2017, 10, 24)
legislative_period_19_end = datetime.date(2021, 10, 26)

# %%
#read xml file to pandas dataframe
df = pd.read_xml('..\\data\\MDB_STAMMDATEN.xml', parser="lxml",xpath='//MDB[WAHLPERIODEN//WAHLPERIODE/WP=19]//NAMEN/NAME')
#remove row where HISTORIE_BIS is not empty (these are duplicates)
df = df[df['HISTORIE_BIS'].isnull()]
#add complete name column
df['NAME'] = df['ANREDE_TITEL'] + ' ' + df['VORNAME'] + ' ' + df['NACHNAME']
df['NAME'] = df['NAME'].fillna(df['VORNAME'] + ' ' + df['NACHNAME'])
#remove columns that are not needed
df = df.drop(['ORTSZUSATZ','ADEL','PRAEFIX','HISTORIE_VON','HISTORIE_BIS'],axis=1)
# add columns for legislative period
df['START'] = [legislative_period_19_begin]*len(df)
df['END'] = [legislative_period_19_end]*len(df)

# %%
df
# Out:
#       NACHNAME       VORNAME ANREDE_TITEL AKAD_TITEL                  NAME  \
# 0       Bleser         Peter         None       None          Peter Bleser
# 1       Brecht      Eberhard          Dr.        Dr.   Dr. Eberhard Brecht
# 3         Dehm       Diether          Dr.        Dr.      Dr. Diether Dehm
# 4      Fuchtel  Hans-Joachim         None       None  Hans-Joachim Fuchtel
# 5         Gysi        Gregor          Dr.        Dr.       Dr. Gregor Gysi
# ..         ...           ...          ...        ...                   ...
# 785   Emmerich        Marcel         None       None       Marcel Emmerich
# 786  Wetterich       Susanne         None       None     Susanne Wetterich
# 787      Jäger       Florian         None       None         Florian Jäger
# 788     Gökhan          Zeki         None       None           Zeki Gökhan
# 789   Bollmann        Gereon         None       None       Gereon Bollmann
#
#           START         END
# 0    2017-10-24  2021-10-26
# 1    2017-10-24  2021-10-26
# 3    2017-10-24  2021-10-26
# 4    2017-10-24  2021-10-26
# 5    2017-10-24  2021-10-26
# ..          ...         ...
# 785  2017-10-24  2021-10-26
# 786  2017-10-24  2021-10-26
# 787  2017-10-24  2021-10-26
# 788  2017-10-24  2021-10-26
# 789  2017-10-24  2021-10-26
#
# [750 rows x 7 columns]

# %%
#read excel sheet with MPs that left the Bundestag before the end of the legislative period
exes = pd.read_excel('..\\data\\Ausgeschiedene.xlsx')

#in column 'Abgeordnete/r' and 'Nachfolger/in' remove everything after the first comma
exes['Nachfolger/in'] = exes['Nachfolger/in'].str.split(',').str[0]
exes['Abgeordnete/r'] = exes['Abgeordnete/r'].str.split(',').str[0]

#in columns 'Abgeordnete/r' and 'Nachfolger/in' remove everything after the first bracket
exes['Nachfolger/in'] = exes['Nachfolger/in'].str.split('(').str[0]
exes['Abgeordnete/r'] = exes['Abgeordnete/r'].str.split('(').str[0]

# %%
exes.shape
# Out:
# (41, 4)

# %%
# for the MPs who left/joined parliament during the 19th election period, change start/end date in df

#get index of df where 'name' is the same as x
def get_index(x):
    return df[df['NAME'] == x].index.values.astype(int)


# match all the names from all mps with the ones that left earlier/joined later and change start/end date
for r in exes.index:
    idx = get_index(exes['Abgeordnete/r'][r])
    if len(idx) == 0:
        print(exes['Abgeordnete/r'][r])
    df.loc[idx,'END'] = exes['ausgeschieden'][r]
    idx = get_index(exes['Nachfolger/in'][r])
    if len(idx)==0:
        print(exes['Nachfolger/in'][r])
    df.loc[idx,'START'] = exes['eingetreten'][r]
# Out:
# Prof. Dr. Axel Gehrke
# Axel Troost
# Stephan Kühn
# Reginald Hanke
# Dr. Ursula von der Leyen
# Isabel Mackensen

# %%
df[df['START']!=legislative_period_19_begin]
# Out:
#                    NACHNAME      VORNAME   ANREDE_TITEL     AKAD_TITEL  \
# 1                    Brecht     Eberhard            Dr.            Dr.
# 38                  Siebert        Bernd           None           None
# 176                  Rawert    Mechthild           None           None
# 354               Fabritius        Bernd  Dr. Dr. h. c.  Dr. Dr. h. c.
# 361            Freudenstein       Astrid            Dr.            Dr.
# 403                   Lotze      Hiltrud           None           None
# 405                Manderla       Gisela           None           None
# 421               Ostermann          Tim            Dr.            Dr.
# 423                Pahlmann       Ingrid           None           None
# 425                 Paschke       Markus           None           None
# 465                  Träger      Carsten           None           None
# 469                Viesehon       Thomas           None           None
# 473                  Warken         Nina           None           None
# 487                    Zech       Tobias           None           None
# 492                   Kovac      Kordula           None           None
# 764                 Völlers  Marja-Liisa           None           None
# 765            Zickenheiner      Gerhard           None           None
# 766                Baradari      Nezahat           None           None
# 767                   Heidt        Peter           None           None
# 770              Weingarten          Joe            Dr.            Dr.
# 771  Schneidewind-Hartnagel    Charlotte           None           None
# 773                 Lehmann       Sylvia           None           None
# 774                  Ludwig       Saskia            Dr.            Dr.
# 775       Bubendorfer-Licht       Sandra           None           None
# 776                    Bach         Bela           None           None
# 777                   Nölke     Matthias           None           None
# 778                  Martin     Dorothee           None           None
# 779                  Wetzel     Wolfgang           None           None
# 780                Natterer    Christian           None           None
# 781                  Dahmen      Janosch            Dr.            Dr.
# 782                   Nordt     Kristina           None           None
# 783        Friemann-Jennert        Maika           None           None
# 784                    Gohl  Christopher            Dr.            Dr.
# 785                Emmerich       Marcel           None           None
# 786               Wetterich      Susanne           None           None
# 787                   Jäger      Florian           None           None
# 788                  Gökhan         Zeki           None           None
# 789                Bollmann       Gereon           None           None
#
#                                  NAME                START  \
# 1                 Dr. Eberhard Brecht  2019-10-25 00:00:00
# 38                      Bernd Siebert  2020-03-02 00:00:00
# 176                  Mechthild Rawert  2020-05-26 00:00:00
# 354     Dr. Dr. h. c. Bernd Fabritius  2021-03-22 00:00:00
# 361           Dr. Astrid Freudenstein  2019-07-02 00:00:00
# 403                     Hiltrud Lotze  2020-11-24 00:00:00
# 405                   Gisela Manderla  2018-11-05 00:00:00
# 421                 Dr. Tim Ostermann  2021-05-01 00:00:00
# 423                   Ingrid Pahlmann  2019-08-01 00:00:00
# 425                    Markus Paschke  2019-11-04 00:00:00
# 465                    Carsten Träger  2017-12-06 00:00:00
# 469                   Thomas Viesehon  2021-05-08 00:00:00
# 473                       Nina Warken  2018-12-05 00:00:00
# 487                       Tobias Zech  2020-05-25 00:00:00
# 492                     Kordula Kovac  2021-03-17 00:00:00
# 764               Marja-Liisa Völlers  2017-11-23 00:00:00
# 765              Gerhard Zickenheiner  2019-01-01 00:00:00
# 766                  Nezahat Baradari  2019-01-07 00:00:00
# 767                       Peter Heidt  2019-07-01 00:00:00
# 770                Dr. Joe Weingarten  2019-11-01 00:00:00
# 771  Charlotte Schneidewind-Hartnagel  2019-11-01 00:00:00
# 773                    Sylvia Lehmann  2019-12-03 00:00:00
# 774                 Dr. Saskia Ludwig  2019-12-03 00:00:00
# 775          Sandra Bubendorfer-Licht  2019-12-09 00:00:00
# 776                         Bela Bach  2020-02-04 00:00:00
# 777                    Matthias Nölke  2020-04-28 00:00:00
# 778                   Dorothee Martin  2020-05-11 00:00:00
# 779                   Wolfgang Wetzel  2020-10-21 00:00:00
# 780                Christian Natterer  2020-11-11 00:00:00
# 781                Dr. Janosch Dahmen  2020-11-12 00:00:00
# 782                    Kristina Nordt  2021-03-22 00:00:00
# 783            Maika Friemann-Jennert  2021-04-07 00:00:00
# 784              Dr. Christopher Gohl  2021-05-01 00:00:00
# 785                   Marcel Emmerich  2021-06-01 00:00:00
# 786                 Susanne Wetterich  2021-07-01 00:00:00
# 787                     Florian Jäger  2021-07-20 00:00:00
# 788                       Zeki Gökhan  2021-08-19 00:00:00
# 789                   Gereon Bollmann  2021-10-01 00:00:00
#
#                      END
# 1             2021-10-26
# 38            2021-10-26
# 176           2021-10-26
# 354           2021-10-26
# 361  2020-05-15 00:00:00
# 403           2021-10-26
# 405           2021-10-26
# 421           2021-10-26
# 423           2021-10-26
# 425           2021-10-26
# 465           2021-10-26
# 469           2021-10-26
# 473           2021-10-26
# 487  2021-03-19 00:00:00
# 492           2021-10-26
# 764           2021-10-26
# 765           2021-10-26
# 766           2021-10-26
# 767           2021-10-26
# 770           2021-10-26
# 771           2021-10-26
# 773           2021-10-26
# 774           2021-10-26
# 775           2021-10-26
# 776           2021-10-26
# 777           2021-10-26
# 778           2021-10-26
# 779           2021-10-26
# 780           2021-10-26
# 781           2021-10-26
# 782           2021-10-26
# 783           2021-10-26
# 784           2021-10-26
# 785           2021-10-26
# 786           2021-10-26
# 787           2021-10-26
# 788           2021-10-26
# 789           2021-10-26

# %%
df.to_excel('..//data//MPs_WP19.xlsx')

# %%
#I manually changed the dates for the MPs who could not be matched automatically (see excel file) !!!!!!
